# %% [markdown]
# # importing data

# %%
# Importing libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
# Using sqlalchemy to connect with the file which contains the data 
engine = create_engine("sqlite:///../data/raw/CristopherRL.db")
#engine = create_engine('http://potacho.com/files/ironhack/CristopherRL.db')

# %%
# Creating a query to incorporate all 3 tables in one with all the information
query = """ 
SELECT 
personal_info.id, 
position, 
lastName, 
rank_info.name, 
age, 
personal_info."Unnamed: 0", 
gender, 
country, 
image, 
business_info.Source,
business_info.worth,
business_info.worthChange,
business_info.realTimeWorth
FROM personal_info
LEFT JOIN rank_info     ON personal_info.id = rank_info.id
LEFT JOIN business_info ON personal_info.id = business_info.id
ORDER BY position
;
"""

# %%
# Importing data from db file to dataframe
raw_data = pd.read_sql_query(query, engine)
raw_data.head(5)
# Out:
#      id  position    lastName             name           age  Unnamed: 0  \
# 0  8254       1.0       bEZOS       jefF BEZOS  54 years old          52
# 1  6688       2.0       gaTEs       bill GATES  62 years old          53
# 2  1904       3.0     bUFFETT   WARREN BUffett  87 years old          54
# 3  4168       4.0     aRNAULT  bernARD Arnault  69 years old          55
# 4  7545       5.0  zuckeRBERG  maRK ZUCKERBERG          1985          56
#
#   gender        country                                              image  \
# 0   Male           None  https://specials-images.forbesimg.com/imageser...
# 1   None           None  https://specials-images.forbesimg.com/imageser...
# 2      M  United States  https://specials-images.forbesimg.com/imageser...
# 3      M           None  https://specials-images.forbesimg.com/imageser...
# 4      M           None  https://specials-images.forbesimg.com/imageser...
#
#                                             Source       worth  \
# 0                           Technology  ==> Amazon  112.0 BUSD
# 1                        Technology  ==> Microsoft   90.0 BUSD
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                         Technology  ==> Facebook   71.0 BUSD
#
#            worthChange realTimeWorth
# 0     0.0 millions USD          None
# 1  -0.001 millions USD          None
# 2  -0.002 millions USD          None
# 3     0.0 millions USD          None
# 4     0.0 millions USD          None

# %% [markdown]
# # Wrangling data

# %%
import re

# %%
proc_data = raw_data

# %%
proc_data.shape
# Out:
# (2208, 13)

# %%
#Analyzing the type of every column
proc_data.dtypes
# Out:
# id                 int64
# position         float64
# lastName          object
# name              object
# age               object
# Unnamed: 0         int64
# gender            object
# country           object
# image             object
# Source            object
# worth             object
# worthChange       object
# realTimeWorth     object
# dtype: object

# %%
proc_data.columns
# Out:
# Index(['id', 'position', 'lastName', 'name', 'age', 'Unnamed: 0', 'gender',
#        'country', 'image', 'Source', 'worth', 'worthChange', 'realTimeWorth'],
#       dtype='object')

# %%
null_cols = proc_data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# age                65
# gender             13
# realTimeWorth    2208
# dtype: int64

# %%
null_displ = proc_data[(proc_data['age'].isnull()==True)]
null_displ
# Out:
#         id  position      lastName                   name   age  Unnamed: 0  \
# 54    1393      55.0       HINDUJA         hiNDUJA Family  None         106
# 76    2609      77.0          KWOK  thomaS & RAYMOND kwok  None         128
# 89    6060      90.0        reUBEN   dAVID & SIMON REUBen  None         141
# 129   7458     130.0       TSCHIRA   udo & HARALD TSCHIRA  None         181
# 141   3572     142.0            NG     ROBERT & PHIlip ng  None         193
# ...    ...       ...           ...                    ...   ...         ...
# 2020  1160    2021.0  chIARAVANOND      yupa chiARavanond  None        2072
# 2021  2877    2022.0   CHIRAVAnond    PRATHIP CHIRAVanond  None        2073
# 2028  3859    2029.0         EGGEr         wolFGANG EGGER  None        2080
# 2044  6241    2045.0         kaPUr            madhu KApur  None        2096
# 2117  2165    2118.0           xIE              sWIFT Xie  None        2169
#
#      gender    country                                              image  \
# 54     None       None  https://specials-images.forbesimg.com/imageser...
# 76     Male  Hong Kong  https://specials-images.forbesimg.com/imageser...
# 89        M       None  https://specials-images.forbesimg.com/imageser...
# 129    Male       None  https://specials-images.forbesimg.com/imageser...
# 141       M       None  https://specials-images.forbesimg.com/imageser...
# ...     ...        ...                                                ...
# 2020      F       None  https://specials-images.forbesimg.com/imageser...
# 2021   Male       None  https://specials-images.forbesimg.com/imageser...
# 2028      M       None  https://specials-images.forbesimg.com/imageser...
# 2044   None       None  https://specials-images.forbesimg.com/imageser...
# 2117   None      China  https://specials-images.forbesimg.com/imageser...
#
#                                          Source      worth  \
# 54                 Diversified  ==> diversified  19.5 BUSD
# 76                 Real Estate  ==> real estate  16.5 BUSD
# 89    Real Estate  ==> investments, real estate  15.5 BUSD
# 129                    Technology  ==> software  11.7 BUSD
# 141                Real Estate  ==> real estate  10.8 BUSD
# ...                                         ...        ...
# 2020               Diversified  ==> diversified   1.1 BUSD
# 2021               Diversified  ==> diversified   1.1 BUSD
# 2028               Real Estate  ==> real estate   1.1 BUSD
# 2044       Finance and Investments  ==> banking   1.1 BUSD
# 2117                     Technology  ==> drones   1.1 BUSD
#
#              worthChange realTimeWorth
# 54    0.001 millions USD          None
# 76      0.0 millions USD          None
# 89      0.0 millions USD          None
# 129     0.0 millions USD          None
# 141     0.0 millions USD          None
# ...                  ...           ...
# 2020    0.0 millions USD          None
# 2021    0.0 millions USD          None
# 2028    nan millions USD          None
# 2044    0.0 millions USD          None
# 2117    0.0 millions USD          None
#
# [65 rows x 13 columns]

# %%
#Changing the data inside some columns

#Age
def real_age(x):
    
    if x is None:
        return 999 #to identify which doesnt have age informatio
    
    else:
        y = re.findall('[\d]+',x) # extracting y from "y years". The last on is '99 years'
        if int(y[0])<100:
            return int(y[0])
        else:
            return 2019-int(y[0]) #there are some people with year of birth
#applying function in every value and changing to int format
proc_data['n_age'] = proc_data['age'].apply(real_age).astype('int64')

# %%
#gender
proc_data['gender'] = proc_data['gender'].fillna("Unknown")
proc_data.loc[proc_data['gender']=='None', 'gender'] = "Unknown"
proc_data.loc[proc_data['gender']=='M', 'gender'] = "Male"
proc_data.loc[proc_data['gender']=='F', 'gender'] = "Female"

#proc_data.loc[(proc_data==None), 'gender'] = "Unknown"

# %%
#being sure that there are just 3 values
list(proc_data['gender'].unique())
# Out:
# ['Male', 'Unknown', 'Female']

# %%
#last name
proc_data['LastName'] = proc_data['lastName'].str.upper()
#name
proc_data['Name'] = proc_data['name'].str.upper()

# %%
list(proc_data['country'].unique())
# Out:
# ['None',
#  'United States',
#  'Hong Kong',
#  'China',
#  'Germany',
#  'Brazil',
#  'France',
#  'Canada',
#  'USA',
#  'Japan',
#  'India',
#  'South Korea',
#  'Indonesia',
#  'United Kingdom',
#  'Russia',
#  'Nigeria',
#  'Colombia',
#  "People's Republic of China",
#  'Mexico',
#  'New Zealand',
#  'Switzerland',
#  'Italy',
#  'Sweden',
#  'Singapore',
#  'South Africa',
#  'UK',
#  'Philippines',
#  'Ukraine',
#  'Israel',
#  'Australia',
#  'Denmark',
#  'Portugal',
#  'Chile',
#  'Czech Republic',
#  'Venezuela',
#  'Vietnam',
#  'Thailand',
#  'United Arab Emirates',
#  'Turkey',
#  'Norway',
#  'Malaysia',
#  'Kazakhstan',
#  'Taiwan',
#  'Poland',
#  'Netherlands',
#  'Lebanon',
#  'Argentina',
#  'Spain',
#  'Monaco',
#  'Belgium',
#  'Cyprus',
#  'Peru',
#  'Tanzania',
#  'Austria',
#  'Finland',
#  'Oman',
#  'Qatar',
#  'Romania',
#  'St. Kitts and Nevis',
#  'Ireland']

# %%
#worth

# %%
#Changing every column to the correct type
proc_data['id']       = proc_data['id'].astype('object') 
proc_data['position'] = proc_data['position'].astype('int64')

# %%
proc_data.head(10)
# Out:
#      id  position    lastName              name           age  Unnamed: 0  \
# 0  8254         1       bEZOS        jefF BEZOS  54 years old          52
# 1  6688         2       gaTEs        bill GATES  62 years old          53
# 2  1904         3     bUFFETT    WARREN BUffett  87 years old          54
# 3  4168         4     aRNAULT   bernARD Arnault  69 years old          55
# 4  7545         5  zuckeRBERG   maRK ZUCKERBERG          1985          56
# 5  2790         6      ortEGA    AMANCIO ORTEGa  82 years old          57
# 6  8711         7   slim HELU  carLOS SLIM HELU  78 years old          58
# 7  1066         8        koCH      chARLES Koch  82 years old          59
# 8  5843         9        kOCH        daVID KOCH  78 years old          60
# 9  1718        10     ELLISON     laRRY ELLISon  73 years old          61
#
#     gender        country                                              image  \
# 0     Male           None  https://specials-images.forbesimg.com/imageser...
# 1  Unknown           None  https://specials-images.forbesimg.com/imageser...
# 2     Male  United States  https://specials-images.forbesimg.com/imageser...
# 3     Male           None  https://specials-images.forbesimg.com/imageser...
# 4     Male           None  https://specials-images.forbesimg.com/imageser...
# 5     Male           None  https://specials-images.forbesimg.com/imageser...
# 6     Male           None  https://specials-images.forbesimg.com/imageser...
# 7     Male           None  https://specials-images.forbesimg.com/imageser...
# 8     Male  United States  https://specials-images.forbesimg.com/imageser...
# 9  Unknown  United States  https://specials-images.forbesimg.com/imageser...
#
#                                             Source       worth  \
# 0                           Technology  ==> Amazon  112.0 BUSD
# 1                        Technology  ==> Microsoft   90.0 BUSD
# 2  Finance and Investments  ==> Berkshire Hathaway   84.0 BUSD
# 3                       Fashion & Retail  ==> LVMH   72.0 BUSD
# 4                         Technology  ==> Facebook   71.0 BUSD
# 5                       Fashion & Retail  ==> Zara   70.0 BUSD
# 6                             Telecom  ==> telecom   67.1 BUSD
# 7                 Diversified  ==> Koch Industries   60.0 BUSD
# 8                 Diversified  ==> Koch Industries   60.0 BUSD
# 9                         Technology  ==> software   58.5 BUSD
#
#            worthChange realTimeWorth  modif_age    LastName              Name
# 0     0.0 millions USD          None         54       BEZOS        JEFF BEZOS
# 1  -0.001 millions USD          None         62       GATES        BILL GATES
# 2  -0.002 millions USD          None         87     BUFFETT    WARREN BUFFETT
# 3     0.0 millions USD          None         69     ARNAULT   BERNARD ARNAULT
# 4     0.0 millions USD          None         34  ZUCKERBERG   MARK ZUCKERBERG
# 5     0.0 millions USD          None         82      ORTEGA    AMANCIO ORTEGA
# 6   0.001 millions USD          None         78   SLIM HELU  CARLOS SLIM HELU
# 7     0.0 millions USD          None         82        KOCH      CHARLES KOCH
# 8     0.0 millions USD          None         78        KOCH        DAVID KOCH
# 9  -0.001 millions USD          None         73     ELLISON     LARRY ELLISON
